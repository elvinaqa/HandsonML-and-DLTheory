# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
intents_file = open('intents.json').read()
intents = json.loads(intents_file)

# %%
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        #add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['How', 'you', 'could', 'help', 'me', '?'], 'options'), (['What', 'you', 'can', 'do', '?'], 'options'), (['What', 'help', 'you', 'provide', '?'], 'options'), (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'), (['What', 'support', 'is', 'offered'], 'options'), (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'), (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'), (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug'), (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug'), (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug'), (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'), (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'), (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'), (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search'), (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'), (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'), (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search'), (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search'), (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'), (['Find', 'pharmacy'], 'pharmacy_search'), (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'), (['Locate', 'pharmacy'], 'pharmacy_search'), (['Search', 'pharmacy'], 'pharmacy_search'), (['Lookup', 'for', 'hospital'], 'hospital_search'), (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search'), (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'), (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'), (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatized words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
training = []
# create empty array for the output
output_empty = [0] * len(classes)
# training set, bag of words for every sentence
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    word_patterns = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    # create the bag of words array with 1, if word is found in current pattern
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle the features and make numpy array
random.shuffle(training)
training = np.array(training)
# create training and testing lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data is created")
# Out:
# Training data is created

# %%
# deep neural networds model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#Training and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model is created")
# Out:
# Epoch 1/200
# 47/47 [==============================] - 1s 21ms/step - loss: 2.2370 - accuracy: 0.1915
# Epoch 2/200
# 47/47 [==============================] - 0s 830us/step - loss: 2.2051 - accuracy: 0.1064
# Epoch 3/200
# 47/47 [==============================] - 0s 785us/step - loss: 2.0387 - accuracy: 0.2553
# Epoch 4/200
# 47/47 [==============================] - 0s 983us/step - loss: 2.0175 - accuracy: 0.3404
# Epoch 5/200
# 47/47 [==============================] - 0s 1ms/step - loss: 1.8790 - accuracy: 0.3617
# Epoch 6/200
# 47/47 [==============================] - 0s 1ms/step - loss: 1.7822 - accuracy: 0.5532
# Epoch 7/200
# 47/47 [==============================] - 0s 1ms/step - loss: 1.7164 - accuracy: 0.5106
# Epoch 8/200
# 47/47 [==============================] - 0s 1ms/step - loss: 1.6121 - accuracy: 0.4894
# Epoch 9/200
# 47/47 [==============================] - 0s 944us/step - loss: 1.4256 - accuracy: 0.5957
# Epoch 10/200
# 47/47 [==============================] - 0s 1ms/step - loss: 1.3301 - accuracy: 0.6383
# Epoch 11/200
# 47/47 [==============================] - 0s 957us/step - loss: 1.2611 - accuracy: 0.5957
# Epoch 12/200
# 47/47 [==============================] - 0s 918us/step - loss: 1.1607 - accuracy: 0.6596
# Epoch 13/200
# 47/47 [==============================] - 0s 998us/step - loss: 0.9381 - accuracy: 0.7660
# Epoch 14/200
# 47/47 [==============================] - 0s 976us/step - loss: 1.0030 - accuracy: 0.7021
# Epoch 15/200
# 47/47 [==============================] - 0s 997us/step - loss: 0.8781 - accuracy: 0.7660
# Epoch 16/200
# 47/47 [==============================] - 0s 952us/step - loss: 0.6979 - accuracy: 0.8511
# Epoch 17/200
# 47/47 [==============================] - 0s 903us/step - loss: 0.8235 - accuracy: 0.7872
# Epoch 18/200
# 47/47 [==============================] - 0s 934us/step - loss: 0.5666 - accuracy: 0.8511
# Epoch 19/200
# 47/47 [==============================] - 0s 938us/step - loss: 0.5795 - accuracy: 0.8723
# Epoch 20/200
# 47/47 [==============================] - 0s 954us/step - loss: 0.4537 - accuracy: 0.9362
# Epoch 21/200
# 47/47 [==============================] - 0s 998us/step - loss: 0.5239 - accuracy: 0.8511
# Epoch 22/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4675 - accuracy: 0.8936
# Epoch 23/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4180 - accuracy: 0.8723
# Epoch 24/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3694 - accuracy: 0.9149
# Epoch 25/200
# 47/47 [==============================] - 0s 997us/step - loss: 0.4471 - accuracy: 0.8511
# Epoch 26/200
# 47/47 [==============================] - 0s 976us/step - loss: 0.3954 - accuracy: 0.8511
# Epoch 27/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2157 - accuracy: 0.9574
# Epoch 28/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3669 - accuracy: 0.9362
# Epoch 29/200
# 47/47 [==============================] - 0s 962us/step - loss: 0.3252 - accuracy: 0.9574
# Epoch 30/200
# 47/47 [==============================] - 0s 871us/step - loss: 0.3614 - accuracy: 0.8723
# Epoch 31/200
# 47/47 [==============================] - 0s 851us/step - loss: 0.1978 - accuracy: 0.9574
# Epoch 32/200
# 47/47 [==============================] - 0s 943us/step - loss: 0.4388 - accuracy: 0.8936
# Epoch 33/200
# 47/47 [==============================] - 0s 866us/step - loss: 0.1608 - accuracy: 1.0000
# Epoch 34/200
# 47/47 [==============================] - 0s 912us/step - loss: 0.2355 - accuracy: 0.9362
# Epoch 35/200
# 47/47 [==============================] - 0s 955us/step - loss: 0.2269 - accuracy: 0.9574
# Epoch 36/200
# 47/47 [==============================] - 0s 946us/step - loss: 0.1983 - accuracy: 0.9574
# Epoch 37/200
# 47/47 [==============================] - 0s 976us/step - loss: 0.2982 - accuracy: 0.9149
# Epoch 38/200
# 47/47 [==============================] - 0s 967us/step - loss: 0.2566 - accuracy: 0.9574
# Epoch 39/200
# 47/47 [==============================] - 0s 955us/step - loss: 0.1323 - accuracy: 0.9787
# Epoch 40/200
# 47/47 [==============================] - 0s 934us/step - loss: 0.2176 - accuracy: 0.9787
# Epoch 41/200
# 47/47 [==============================] - 0s 891us/step - loss: 0.1993 - accuracy: 0.9574
# Epoch 42/200
# 47/47 [==============================] - 0s 956us/step - loss: 0.1067 - accuracy: 0.9787
# Epoch 43/200
# 47/47 [==============================] - 0s 948us/step - loss: 0.1954 - accuracy: 0.9362
# Epoch 44/200
# 47/47 [==============================] - 0s 912us/step - loss: 0.1823 - accuracy: 0.9574
# Epoch 45/200
# 47/47 [==============================] - 0s 968us/step - loss: 0.1096 - accuracy: 0.9787
# Epoch 46/200
# 47/47 [==============================] - 0s 913us/step - loss: 0.0676 - accuracy: 1.0000
# Epoch 47/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2918 - accuracy: 0.9149
# Epoch 48/200
# 47/47 [==============================] - 0s 975us/step - loss: 0.1177 - accuracy: 0.9787
# Epoch 49/200
# 47/47 [==============================] - 0s 953us/step - loss: 0.0986 - accuracy: 0.9787
# Epoch 50/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1365 - accuracy: 0.9787
# Epoch 51/200
# 47/47 [==============================] - 0s 978us/step - loss: 0.1347 - accuracy: 0.9574
# Epoch 52/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0978 - accuracy: 1.0000
# Epoch 53/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0961 - accuracy: 1.0000
# Epoch 54/200
# 47/47 [==============================] - 0s 957us/step - loss: 0.2057 - accuracy: 0.8723
# Epoch 55/200
# 47/47 [==============================] - 0s 956us/step - loss: 0.1068 - accuracy: 0.9574
# Epoch 56/200
# 47/47 [==============================] - 0s 892us/step - loss: 0.1058 - accuracy: 0.9574
# Epoch 57/200
# 47/47 [==============================] - 0s 870us/step - loss: 0.1277 - accuracy: 0.9362
# Epoch 58/200
# 47/47 [==============================] - 0s 885us/step - loss: 0.0486 - accuracy: 1.0000
# Epoch 59/200
# 47/47 [==============================] - 0s 805us/step - loss: 0.1026 - accuracy: 0.9787
# Epoch 60/200
# 47/47 [==============================] - 0s 829us/step - loss: 0.1317 - accuracy: 0.9574
# Epoch 61/200
# 47/47 [==============================] - 0s 908us/step - loss: 0.1189 - accuracy: 0.9574
# Epoch 62/200
# 47/47 [==============================] - 0s 806us/step - loss: 0.0699 - accuracy: 1.0000
# Epoch 63/200
# 47/47 [==============================] - 0s 845us/step - loss: 0.1125 - accuracy: 0.9787
# Epoch 64/200
# 47/47 [==============================] - 0s 912us/step - loss: 0.0553 - accuracy: 0.9787
# Epoch 65/200
# 47/47 [==============================] - 0s 912us/step - loss: 0.1030 - accuracy: 0.9787
# Epoch 66/200
# 47/47 [==============================] - 0s 913us/step - loss: 0.1049 - accuracy: 1.0000
# Epoch 67/200
# 47/47 [==============================] - 0s 828us/step - loss: 0.0482 - accuracy: 1.0000
# Epoch 68/200
# 47/47 [==============================] - 0s 849us/step - loss: 0.0641 - accuracy: 1.0000
# Epoch 69/200
# 47/47 [==============================] - 0s 829us/step - loss: 0.0513 - accuracy: 1.0000
# Epoch 70/200
# 47/47 [==============================] - 0s 847us/step - loss: 0.1120 - accuracy: 0.9787
# Epoch 71/200
# 47/47 [==============================] - 0s 868us/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 72/200
# 47/47 [==============================] - 0s 934us/step - loss: 0.0589 - accuracy: 1.0000
# Epoch 73/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1046 - accuracy: 0.9787
# Epoch 74/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0993 - accuracy: 1.0000
# Epoch 75/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0574 - accuracy: 1.0000
# Epoch 76/200
# 47/47 [==============================] - 0s 974us/step - loss: 0.0562 - accuracy: 1.0000
# Epoch 77/200
# 47/47 [==============================] - 0s 890us/step - loss: 0.0871 - accuracy: 0.9787
# Epoch 78/200
# 47/47 [==============================] - 0s 893us/step - loss: 0.0665 - accuracy: 0.9787
# Epoch 79/200
# 47/47 [==============================] - 0s 831us/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 80/200
# 47/47 [==============================] - 0s 870us/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 81/200
# 47/47 [==============================] - 0s 780us/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 82/200
# 47/47 [==============================] - 0s 808us/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 83/200
# 47/47 [==============================] - 0s 792us/step - loss: 0.0759 - accuracy: 0.9787
# Epoch 84/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0484 - accuracy: 1.0000
# Epoch 85/200
# 47/47 [==============================] - 0s 849us/step - loss: 0.0717 - accuracy: 1.0000
# Epoch 86/200
# 47/47 [==============================] - 0s 882us/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 87/200
# 47/47 [==============================] - 0s 850us/step - loss: 0.0690 - accuracy: 0.9787
# Epoch 88/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0464 - accuracy: 1.0000
# Epoch 89/200
# 47/47 [==============================] - 0s 912us/step - loss: 0.0934 - accuracy: 0.9787
# Epoch 90/200
# 47/47 [==============================] - 0s 849us/step - loss: 0.0396 - accuracy: 0.9787
# Epoch 91/200
# 47/47 [==============================] - 0s 891us/step - loss: 0.0543 - accuracy: 0.9787
# Epoch 92/200
# 47/47 [==============================] - 0s 858us/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 93/200
# 47/47 [==============================] - 0s 891us/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 94/200
# 47/47 [==============================] - 0s 877us/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 95/200
# 47/47 [==============================] - 0s 934us/step - loss: 0.0543 - accuracy: 0.9787
# Epoch 96/200
# 47/47 [==============================] - 0s 914us/step - loss: 0.0533 - accuracy: 1.0000
# Epoch 97/200
# 47/47 [==============================] - 0s 792us/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 98/200
# 47/47 [==============================] - 0s 933us/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 99/200
# 47/47 [==============================] - 0s 956us/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 100/200
# 47/47 [==============================] - 0s 839us/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 101/200
# 47/47 [==============================] - 0s 785us/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 102/200
# 47/47 [==============================] - 0s 976us/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 103/200
# 47/47 [==============================] - 0s 998us/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 104/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0339 - accuracy: 0.9787
# Epoch 105/200
# 47/47 [==============================] - 0s 957us/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 106/200
# 47/47 [==============================] - 0s 872us/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 107/200
# 47/47 [==============================] - 0s 806us/step - loss: 0.0516 - accuracy: 1.0000
# Epoch 108/200
# 47/47 [==============================] - 0s 891us/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 109/200
# 47/47 [==============================] - 0s 955us/step - loss: 0.0582 - accuracy: 0.9787
# Epoch 110/200
# 47/47 [==============================] - 0s 828us/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 111/200
# 47/47 [==============================] - 0s 891us/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 112/200
# 47/47 [==============================] - 0s 999us/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 113/200
# 47/47 [==============================] - 0s 892us/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 114/200
# 47/47 [==============================] - 0s 864us/step - loss: 0.0444 - accuracy: 1.0000
# Epoch 115/200
# 47/47 [==============================] - 0s 891us/step - loss: 0.0446 - accuracy: 0.9787
# Epoch 116/200
# 47/47 [==============================] - 0s 915us/step - loss: 0.0482 - accuracy: 0.9787
# Epoch 117/200
# 47/47 [==============================] - 0s 942us/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 118/200
# 47/47 [==============================] - 0s 853us/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 119/200
# 47/47 [==============================] - 0s 840us/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 120/200
# 47/47 [==============================] - 0s 850us/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 121/200
# 47/47 [==============================] - 0s 852us/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 122/200
# 47/47 [==============================] - 0s 807us/step - loss: 0.0739 - accuracy: 0.9574
# Epoch 123/200
# 47/47 [==============================] - 0s 912us/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 124/200
# 47/47 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 1.00 - 0s 1ms/step - loss: 0.1469 - accuracy: 0.9787
# Epoch 125/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0365 - accuracy: 0.9787
# Epoch 126/200
# 47/47 [==============================] - 0s 919us/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 127/200
# 47/47 [==============================] - 0s 948us/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 128/200
# 47/47 [==============================] - 0s 888us/step - loss: 0.0408 - accuracy: 0.9787
# Epoch 129/200
# 47/47 [==============================] - 0s 874us/step - loss: 0.0487 - accuracy: 1.0000
# Epoch 130/200
# 47/47 [==============================] - 0s 849us/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 131/200
# 47/47 [==============================] - 0s 867us/step - loss: 0.0768 - accuracy: 0.9787
# Epoch 132/200
# 47/47 [==============================] - 0s 912us/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 133/200
# 47/47 [==============================] - 0s 997us/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 134/200
# 47/47 [==============================] - 0s 992us/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 135/200
# 47/47 [==============================] - 0s 912us/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 136/200
# 47/47 [==============================] - 0s 939us/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 137/200
# 47/47 [==============================] - 0s 861us/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 138/200
# 47/47 [==============================] - 0s 849us/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 139/200
# 47/47 [==============================] - 0s 892us/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 140/200
# 47/47 [==============================] - 0s 912us/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 141/200
# 47/47 [==============================] - 0s 997us/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 142/200
# 47/47 [==============================] - 0s 891us/step - loss: 0.0504 - accuracy: 0.9787
# Epoch 143/200
# 47/47 [==============================] - 0s 806us/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 144/200
# 47/47 [==============================] - 0s 807us/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 145/200
# 47/47 [==============================] - 0s 849us/step - loss: 0.0336 - accuracy: 0.9787
# Epoch 146/200
# 47/47 [==============================] - 0s 874us/step - loss: 0.0932 - accuracy: 0.9362
# Epoch 147/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 148/200
# 47/47 [==============================] - 0s 852us/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 149/200
# 47/47 [==============================] - 0s 830us/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 150/200
# 47/47 [==============================] - 0s 747us/step - loss: 0.0447 - accuracy: 0.9787
# Epoch 151/200
# 47/47 [==============================] - 0s 828us/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 152/200
# 47/47 [==============================] - 0s 809us/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 153/200
# 47/47 [==============================] - 0s 891us/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 154/200
# 47/47 [==============================] - 0s 933us/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 155/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 156/200
# 47/47 [==============================] - 0s 954us/step - loss: 0.0427 - accuracy: 0.9787
# Epoch 157/200
# 47/47 [==============================] - 0s 914us/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 158/200
# 47/47 [==============================] - 0s 963us/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 159/200
# 47/47 [==============================] - 0s 912us/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 160/200
# 47/47 [==============================] - 0s 955us/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 161/200
# 47/47 [==============================] - 0s 934us/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 162/200
# 47/47 [==============================] - 0s 955us/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 163/200
# 47/47 [==============================] - 0s 861us/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 164/200
# 47/47 [==============================] - 0s 907us/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 165/200
# 47/47 [==============================] - 0s 914us/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 166/200
# 47/47 [==============================] - 0s 891us/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 167/200
# 47/47 [==============================] - 0s 955us/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 168/200
# 47/47 [==============================] - 0s 891us/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 169/200
# 47/47 [==============================] - 0s 904us/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 170/200
# 47/47 [==============================] - 0s 891us/step - loss: 0.0629 - accuracy: 0.9787
# Epoch 171/200
# 47/47 [==============================] - 0s 936us/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 172/200
# 47/47 [==============================] - 0s 908us/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 173/200
# 47/47 [==============================] - 0s 868us/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 174/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 175/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 176/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 177/200
# 47/47 [==============================] - 0s 867us/step - loss: 0.0299 - accuracy: 0.9787
# Epoch 178/200
# 47/47 [==============================] - 0s 828us/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 179/200
# 47/47 [==============================] - 0s 828us/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 180/200
# 47/47 [==============================] - 0s 894us/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 181/200
# 47/47 [==============================] - 0s 945us/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 182/200
# 47/47 [==============================] - 0s 978us/step - loss: 0.0342 - accuracy: 0.9787
# Epoch 183/200
# 47/47 [==============================] - 0s 919us/step - loss: 0.0337 - accuracy: 0.9787
# Epoch 184/200
# 47/47 [==============================] - 0s 930us/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 185/200
# 47/47 [==============================] - 0s 912us/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 186/200
# 47/47 [==============================] - 0s 982us/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 187/200
# 47/47 [==============================] - 0s 958us/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 188/200
# 47/47 [==============================] - 0s 955us/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 189/200
# 47/47 [==============================] - 0s 849us/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 190/200
# 47/47 [==============================] - 0s 912us/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 191/200
# 47/47 [==============================] - 0s 861us/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 192/200
# 47/47 [==============================] - 0s 806us/step - loss: 0.0423 - accuracy: 0.9787
# Epoch 193/200
# 47/47 [==============================] - 0s 976us/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 194/200
# 47/47 [==============================] - 0s 934us/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 195/200
# 47/47 [==============================] - 0s 939us/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 196/200
# 47/47 [==============================] - 0s 934us/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 197/200
# 47/47 [==============================] - 0s 934us/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 198/200
# 47/47 [==============================] - 0s 956us/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 199/200
# 47/47 [==============================] - 0s 932us/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 200/200
# 47/47 [==============================] - 0s 891us/step - loss: 0.0679 - accuracy: 0.9787
# model is created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))
def clean_up_sentence(sentence):
    # tokenize the pattern - splitting words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stemming every word - reducing to base form
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for words that exist in sentence
def bag_of_words(sentence, words, show_details=True):
    # tokenizing patterns
    sentence_words = clean_up_sentence(sentence)
    # bag of words - vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,word in enumerate(words):
            if word == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % word)
    return(np.array(bag))
def predict_class(sentence):
    # filter below  threshold predictions
    p = bag_of_words(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sorting strength probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
#Creating tkinter GUI
import tkinter
from tkinter import *
def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatBox.config(state=NORMAL)
        ChatBox.insert(END, "You: " + msg + '\n\n')
        ChatBox.config(foreground="#446665", font=("Verdana", 12 ))
        ints = predict_class(msg)
        res = getResponse(ints, intents)
        ChatBox.insert(END, "Bot: " + res + '\n\n')
        ChatBox.config(state=DISABLED)
        ChatBox.yview(END)
root = Tk()
root.title("Chatbot")
root.geometry("400x500")
root.resizable(width=FALSE, height=FALSE)
#Create Chat window
ChatBox = Text(root, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatBox.config(state=DISABLED)
#Bind scrollbar to Chat window
scrollbar = Scrollbar(root, command=ChatBox.yview, cursor="heart")
ChatBox['yscrollcommand'] = scrollbar.set
#Create Button to send message
SendButton = Button(root, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#f9a602", activebackground="#3c9d9b",fg='#000000',
                    command= send )
#Create the box to enter message
EntryBox = Text(root, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)
#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatBox.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)
root.mainloop()
